# %%
import pandas as pd
df = pd.read_excel('missing data.xlsx')
df
# Out:
#      e_code  status  hire_date service_agreement  job_level  \
# 0     45631       0 1990-09-17                 N          3
# 1     45632       0 1995-10-23                 N          2
# 2     45633       0 1996-03-10                 N          2
# 3     45634       0 1998-07-13                 N          1
# 4     45635       0 1991-09-16                 N          2
# ..      ...     ...        ...               ...        ...
# 688   45649       0 2002-03-12                 N          1
# 689   45650       0 2002-10-18                 N          2
# 690   45651       0 1997-03-31                 N          1
# 691   45652       0 1999-04-19                 N          1
# 692   45653       0 2001-02-20                 Y          1
#
#      performance_rating_2018  performance_rating_2017  year_of_birth gender  \
# 0                          4                        3           1967      M
# 1                          1                        2           1971      M
# 2                          4                        4           1972      M
# 3                          3                        3           1968      F
# 4                          3                        3           1961      M
# ..                       ...                      ...            ...    ...
# 688                        5                        4           1977      M
# 689                        3                        3           1964      M
# 690                        4                        4           1971      F
# 691                        1                        1           1970      M
# 692                        4                        3           1974      M
#
#      distance_from_home  ...  potential_rating  bonus no_courses_taken  \
# 0                  0.52  ...                 5      0                8
# 1                  0.08  ...                 5   2242                6
# 2                  0.51  ...                 3      0                2
# 3                  0.81  ...                 5   2320                2
# 4                  0.06  ...                 5      0               10
# ..                  ...  ...               ...    ...              ...
# 688                0.18  ...                 3   2969               16
# 689                0.35  ...                 5   2899                2
# 690                0.39  ...                 3      0                2
# 691                0.08  ...                 5   2861                2
# 692                1.51  ...                 2      0               11
#
#      time_in_position  awards  signon  manager_sat employee_sat salary_2017  \
# 0                  30       N       N           81         80.0      119968
# 1                   5       N       N           88         84.0       99330
# 2                  53       N       N           83         93.0      102511
# 3                  36       N       N           86         83.0       56674
# 4                   2       N       N           79         80.0      122021
# ..                ...     ...     ...          ...          ...         ...
# 688                 5       N       N           92         81.0       53024
# 689                51       N       N           84          NaN       93813
# 690                48       N       N           82         80.0       85800
# 691               115       Y       N           90         80.0       56635
# 692                 3       N       N           84         74.0       54780
#
#      salary_2018
# 0         124173
# 1         100822
# 2         115500
# 3          58806
# 4         122021
# ..           ...
# 688        57803
# 689        96631
# 690        91377
# 691        56635
# 692        62997
#
# [693 rows x 23 columns]

# %%
df.isna().sum()
# Out:
# e_code                      0
# status                      0
# hire_date                   0
# service_agreement           0
# job_level                   0
# performance_rating_2018     0
# performance_rating_2017     0
# year_of_birth               0
# gender                      0
# distance_from_home          0
# manager_changes             0
# no_of_promotions            0
# risk_of_attrition          14
# potential_rating            0
# bonus                       0
# no_courses_taken            0
# time_in_position            0
# awards                      0
# signon                      0
# manager_sat                 0
# employee_sat               22
# salary_2017                 0
# salary_2018                 0
# dtype: int64

# %%
df.isna().sum()/df.count()*100
# Out:
# e_code                     0.000000
# status                     0.000000
# hire_date                  0.000000
# service_agreement          0.000000
# job_level                  0.000000
# performance_rating_2018    0.000000
# performance_rating_2017    0.000000
# year_of_birth              0.000000
# gender                     0.000000
# distance_from_home         0.000000
# manager_changes            0.000000
# no_of_promotions           0.000000
# risk_of_attrition          2.061856
# potential_rating           0.000000
# bonus                      0.000000
# no_courses_taken           0.000000
# time_in_position           0.000000
# awards                     0.000000
# signon                     0.000000
# manager_sat                0.000000
# employee_sat               3.278689
# salary_2017                0.000000
# salary_2018                0.000000
# dtype: float64

# %%
df1 = df.dropna()

# %%
df1.isna().sum()
# Out:
# e_code                     0
# status                     0
# hire_date                  0
# service_agreement          0
# job_level                  0
# performance_rating_2018    0
# performance_rating_2017    0
# year_of_birth              0
# gender                     0
# distance_from_home         0
# manager_changes            0
# no_of_promotions           0
# risk_of_attrition          0
# potential_rating           0
# bonus                      0
# no_courses_taken           0
# time_in_position           0
# awards                     0
# signon                     0
# manager_sat                0
# employee_sat               0
# salary_2017                0
# salary_2018                0
# dtype: int64

# %%
df1 = df['employee_sat']
df1 = df1.fillna(0)
df1
# Out:
# 0      80.0
# 1      84.0
# 2      93.0
# 3      83.0
# 4      80.0
#        ...
# 688    81.0
# 689     0.0
# 690    80.0
# 691    80.0
# 692    74.0
# Name: employee_sat, Length: 693, dtype: float64

# %%
df1.isna().sum()
# Out:
# 0

# %%
df1 = df['employee_sat']
df1 = df1.fillna(df1.mean())
df1
# Out:
# 0      80.000000
# 1      84.000000
# 2      93.000000
# 3      83.000000
# 4      80.000000
#          ...
# 688    81.000000
# 689    81.152012
# 690    80.000000
# 691    80.000000
# 692    74.000000
# Name: employee_sat, Length: 693, dtype: float64

# %%
df1.isna().sum()
# Out:
# 0

# %%
df1 = df['employee_sat']
df1 = df1.fillna(df1.median())
df1
# Out:
# 0      80.0
# 1      84.0
# 2      93.0
# 3      83.0
# 4      80.0
#        ...
# 688    81.0
# 689    80.0
# 690    80.0
# 691    80.0
# 692    74.0
# Name: employee_sat, Length: 693, dtype: float64

# %%
df1.isna().sum()
# Out:
# 0

# %%
df1 = df['employee_sat']
df1.value_counts()
# Out:
# 80.0     406
# 74.0      18
# 85.0      14
# 86.0      13
# 87.0      13
# 81.0      13
# 83.0      13
# 76.0      13
# 73.0      12
# 78.0      12
# 89.0      12
# 88.0      11
# 92.0      11
# 77.0      11
# 82.0      11
# 91.0       9
# 90.0       9
# 79.0       8
# 72.0       8
# 75.0       7
# 84.0       7
# 71.0       6
# 93.0       6
# 70.0       6
# 94.0       6
# 100.0      4
# 95.0       4
# 96.0       3
# 97.0       3
# 98.0       2
# Name: employee_sat, dtype: int64

# %%
df1 = df1.fillna(80)

# %%
df1.isna().sum()
# Out:
# 0

# %%
df1 = df

# %%
df1['risk_of_attrition'].value_counts()
# Out:
# LOW          649
# MEDIUM        19
# VERY HIGH      8
# HIGH           3
# Name: risk_of_attrition, dtype: int64

# %%
df2 = df1['risk_of_attrition'].fillna("LOW")

# %%
df2.isna().sum()
# Out:
# 0

# %%
df2
# Out:
# 0      LOW
# 1      LOW
# 2      LOW
# 3      LOW
# 4      LOW
#       ...
# 688    LOW
# 689    LOW
# 690    LOW
# 691    LOW
# 692    LOW
# Name: risk_of_attrition, Length: 693, dtype: object

# %%
df
# Out:
#      e_code  status  hire_date service_agreement  job_level  \
# 0     45631       0 1990-09-17                 N          3
# 1     45632       0 1995-10-23                 N          2
# 2     45633       0 1996-03-10                 N          2
# 3     45634       0 1998-07-13                 N          1
# 4     45635       0 1991-09-16                 N          2
# ..      ...     ...        ...               ...        ...
# 688   45649       0 2002-03-12                 N          1
# 689   45650       0 2002-10-18                 N          2
# 690   45651       0 1997-03-31                 N          1
# 691   45652       0 1999-04-19                 N          1
# 692   45653       0 2001-02-20                 Y          1
#
#      performance_rating_2018  performance_rating_2017  year_of_birth gender  \
# 0                          4                        3           1967      M
# 1                          1                        2           1971      M
# 2                          4                        4           1972      M
# 3                          3                        3           1968      F
# 4                          3                        3           1961      M
# ..                       ...                      ...            ...    ...
# 688                        5                        4           1977      M
# 689                        3                        3           1964      M
# 690                        4                        4           1971      F
# 691                        1                        1           1970      M
# 692                        4                        3           1974      M
#
#      distance_from_home  ...  potential_rating  bonus no_courses_taken  \
# 0                  0.52  ...                 5      0                8
# 1                  0.08  ...                 5   2242                6
# 2                  0.51  ...                 3      0                2
# 3                  0.81  ...                 5   2320                2
# 4                  0.06  ...                 5      0               10
# ..                  ...  ...               ...    ...              ...
# 688                0.18  ...                 3   2969               16
# 689                0.35  ...                 5   2899                2
# 690                0.39  ...                 3      0                2
# 691                0.08  ...                 5   2861                2
# 692                1.51  ...                 2      0               11
#
#      time_in_position  awards  signon  manager_sat employee_sat salary_2017  \
# 0                  30       N       N           81         80.0      119968
# 1                   5       N       N           88         84.0       99330
# 2                  53       N       N           83         93.0      102511
# 3                  36       N       N           86         83.0       56674
# 4                   2       N       N           79         80.0      122021
# ..                ...     ...     ...          ...          ...         ...
# 688                 5       N       N           92         81.0       53024
# 689                51       N       N           84          NaN       93813
# 690                48       N       N           82         80.0       85800
# 691               115       Y       N           90         80.0       56635
# 692                 3       N       N           84         74.0       54780
#
#      salary_2018
# 0         124173
# 1         100822
# 2         115500
# 3          58806
# 4         122021
# ..           ...
# 688        57803
# 689        96631
# 690        91377
# 691        56635
# 692        62997
#
# [693 rows x 23 columns]

# %%
df.shape
# Out:
# (693, 23)

# %%
df.job_level.duplicated()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 688     True
# 689     True
# 690     True
# 691     True
# 692     True
# Name: job_level, Length: 693, dtype: bool

# %%
df.job_level.duplicated().sum
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 688     True
# 689     True
# 690     True
# 691     True
# 692     True
# Name: job_level, Length: 693, dtype: bool>

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 688     True
# 689     True
# 690     True
# 691     True
# 692     True
# Length: 693, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 7

# %%
df.loc[df.duplicated(),:]
# Out:
#      e_code  status  hire_date service_agreement  job_level  \
# 686   45647       0 1992-08-31                 N          1
# 687   45648       0 1995-11-13                 N          1
# 688   45649       0 2002-03-12                 N          1
# 689   45650       0 2002-10-18                 N          2
# 690   45651       0 1997-03-31                 N          1
# 691   45652       0 1999-04-19                 N          1
# 692   45653       0 2001-02-20                 Y          1
#
#      performance_rating_2018  performance_rating_2017  year_of_birth gender  \
# 686                        3                        3           1963      M
# 687                        2                        2           1967      M
# 688                        5                        4           1977      M
# 689                        3                        3           1964      M
# 690                        4                        4           1971      F
# 691                        1                        1           1970      M
# 692                        4                        3           1974      M
#
#      distance_from_home  ...  potential_rating  bonus no_courses_taken  \
# 686                0.02  ...                 5      0                2
# 687                0.98  ...                 5      0                7
# 688                0.18  ...                 3   2969               16
# 689                0.35  ...                 5   2899                2
# 690                0.39  ...                 3      0                2
# 691                0.08  ...                 5   2861                2
# 692                1.51  ...                 2      0               11
#
#      time_in_position  awards  signon  manager_sat employee_sat salary_2017  \
# 686                33       N       N           83         80.0       76646
# 687               135       N       N           81         74.0       75418
# 688                 5       N       N           92         81.0       53024
# 689                51       N       N           84          NaN       93813
# 690                48       N       N           82         80.0       85800
# 691               115       Y       N           90         80.0       56635
# 692                 3       N       N           84         74.0       54780
#
#      salary_2018
# 686        78949
# 687        76930
# 688        57803
# 689        96631
# 690        91377
# 691        56635
# 692        62997
#
# [7 rows x 23 columns]

# %%
df.loc[df.duplicated(keep= 'last'), :]
# Out:
#     e_code  status  hire_date service_agreement  job_level  \
# 11   45647       0 1992-08-31                 N          1
# 12   45648       0 1995-11-13                 N          1
# 13   45649       0 2002-03-12                 N          1
# 14   45650       0 2002-10-18                 N          2
# 15   45651       0 1997-03-31                 N          1
# 16   45652       0 1999-04-19                 N          1
# 17   45653       0 2001-02-20                 Y          1
#
#     performance_rating_2018  performance_rating_2017  year_of_birth gender  \
# 11                        3                        3           1963      M
# 12                        2                        2           1967      M
# 13                        5                        4           1977      M
# 14                        3                        3           1964      M
# 15                        4                        4           1971      F
# 16                        1                        1           1970      M
# 17                        4                        3           1974      M
#
#     distance_from_home  ...  potential_rating  bonus no_courses_taken  \
# 11                0.02  ...                 5      0                2
# 12                0.98  ...                 5      0                7
# 13                0.18  ...                 3   2969               16
# 14                0.35  ...                 5   2899                2
# 15                0.39  ...                 3      0                2
# 16                0.08  ...                 5   2861                2
# 17                1.51  ...                 2      0               11
#
#     time_in_position  awards  signon  manager_sat employee_sat salary_2017  \
# 11                33       N       N           83         80.0       76646
# 12               135       N       N           81         74.0       75418
# 13                 5       N       N           92         81.0       53024
# 14                51       N       N           84          NaN       93813
# 15                48       N       N           82         80.0       85800
# 16               115       Y       N           90         80.0       56635
# 17                 3       N       N           84         74.0       54780
#
#     salary_2018
# 11        78949
# 12        76930
# 13        57803
# 14        96631
# 15        91377
# 16        56635
# 17        62997
#
# [7 rows x 23 columns]

# %%
df.drop_duplicates(keep= 'first').shape
# Out:
# (686, 23)
